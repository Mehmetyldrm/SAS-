# %% [markdown]
# <a href="https://colab.research.google.com/github/Mehmetyldrm/SAS-/blob/master/Billionaire_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

data_set=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datasets/Billionaires Statistics Dataset.csv')
data_set.head()
# Out:
#    rank  finalWorth               category                personName   age  \
# 0     1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1     2      180000             Automotive                 Elon Musk  51.0
# 2     3      114000             Technology                Jeff Bezos  59.0
# 3     4      107000             Technology             Larry Ellison  78.0
# 4     5      106000  Finance & Investments            Warren Buffett  92.0
#
#          country    city              source             industries  \
# 0         France   Paris                LVMH       Fashion & Retail
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
#
#   countryOfCitizenship  ... cpi_change_country           gdp_country  \
# ...

# %%
#Basic statistics of variables
data_set.describe()
# Out:
#               rank     finalWorth          age    birthYear   birthMonth  \
# count  2640.000000    2640.000000  2575.000000  2564.000000  2564.000000
# mean   1289.159091    4623.787879    65.140194  1957.183307     5.740250
# std     739.693726    9834.240939    13.258098    13.282516     3.710085
# min       1.000000    1000.000000    18.000000  1921.000000     1.000000
# 25%     659.000000    1500.000000    56.000000  1948.000000     2.000000
# 50%    1312.000000    2300.000000    65.000000  1957.000000     6.000000
# 75%    1905.000000    4200.000000    75.000000  1966.000000     9.000000
# max    2540.000000  211000.000000   101.000000  2004.000000    12.000000
#
#           birthDay  cpi_country  cpi_change_country  \
# count  2564.000000  2456.000000         2456.000000
# mean     12.099844   127.755204            4.364169
# std       9.918876    26.452951            3.623763
# min       1.000000    99.550000           -1.900000
# ...

# %%
#New column 'Net Worth' will be created for easier representing porpuses

data_set['Net Worth(Billion)']=data_set['finalWorth']/1000

# %%
#Youngest and oldest billioners ages
print('Youngest billioner in the list is ',int( min(data_set['age'])), 'year old.')
print('Oldest billioner in the list is ', int(max(data_set['age'])), 'year old.')
# Out:
# Youngest billioner in the list is  18 year old.
# Oldest billioner in the list is  101 year old.

# %%
#Creating single column for birth date

data_set['birth_date']=pd.to_datetime(dict(year=data_set.birthYear, month=data_set.birthMonth, day=data_set.birthDay))

data_set.birthDate
# Out:
# 0         3/5/1949 0:00
# 1        6/28/1971 0:00
# 2        1/12/1964 0:00
# 3        8/17/1944 0:00
# 4        8/30/1930 0:00
#              ...
# 2635    12/14/1971 0:00
# 2636     3/10/1943 0:00
# 2637    12/18/1962 0:00
# 2638     8/21/1951 0:00
# 2639     11/1/1956 0:00
# Name: birthDate, Length: 2640, dtype: object
